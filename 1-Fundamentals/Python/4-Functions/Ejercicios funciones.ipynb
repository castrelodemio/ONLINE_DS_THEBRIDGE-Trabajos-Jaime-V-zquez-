# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios funciones
# ## Ejercicio 1
# Escribe una función que convierta números del 1 al 7 en nombres de los dias de la semana. La función constará de un único argumento numérico y una salida de tipo string

# %%
def dia_semana(numero):
    if numero == 1:
        return "Lunes"
    elif numero == 2:
        return "Martes"
    elif numero == 3:
        return "Miércoles"
    elif numero == 4:
        return "Jueves"
    elif numero == 5:
        return "Viernes"
    elif numero == 6:
        return "Sábado"
    elif numero == 7:
        return "Domingo"
    else:
        return "El día no existe"

print(dia_semana(1))
print(dia_semana(7))
# Out:
# Lunes
# Domingo

# %%
print(dia_semana(9))
# Out:
# El día no existe

# %% [markdown]
# ## Ejercicio 2
# En el ejercicio 8 de bucles, creábamos una pirámide invertida, cuyo número de pisos venía determinado por un input del usuario. Crear una función que replique el comportamiento de la pirámide, y utiliza un único parámetro de entrada de la función para determinar el número de filas de la pirámide, es decir, elimina la sentencia input.

# %%
def piramide(pisos):
    for i in range(pisos, 0, -1):
        for j in range(1, i+1):
            print(j, end=" ")
        print()

piramide(4)
piramide(6)
# Out:
# 1 2 3 4
# 1 2 3
# 1 2
# 1
# 1 2 3 4 5 6
# 1 2 3 4 5
# 1 2 3 4
# 1 2 3
# 1 2
# 1

# %%
print(piramide(0))
# Out:
# None

# %% [markdown]
# ## Ejercicio 3
# Escibe una función que compare dos números. La función tiene dos argumentos y hay tres salidas posibles: que sean iguales, que el primero se  mayor que el segundo, o que el segundo sea mayor que el primero

# %%
def compara(a, b):
    if a == b:
        return "Son iguales"
    elif a > b:
        return str(a) + " es mayor que " + str(b)
    else:
        return str(b) + " es mayor que " + str(a)

print(compara(4, 3))
print(compara(5, 5))
# Out:
# 4 es mayor que 3
# Son iguales

# %% [markdown]
# ## Ejercicio 4
# Escribe una función que sea un contador de letras. En el primer argumento tienes que introducir un texto, y el segundo que sea la letra a contar. La función tiene que devolver un entero con el número de veces que aparece esa letra, tanto mayuscula, como minúscula

# %%
def cuenta_letra(texto, letra):
    contador = 0
    for caracter in texto.lower():
        if caracter == letra.lower():
            contador += 1
    return contador

cuenta_letra("Hola Mundo", "o")
# Out:
# 2

# %% [markdown]
# ## Ejercicio 5
# Escribe una función que tenga un único argumento, un string. La salida de la función tiene que ser un diccionario con el conteo de todas las letras de ese string.

# %%
def cuenta_letras(texto):
    diccionario = {}
    for letra in texto:
        if letra in diccionario:
            diccionario[letra] += 1
        else:
            diccionario[letra] = 1
    return diccionario

cuenta_letras("en esta clase aprenderemos muchas cosas hoy")
# Out:
# {'e': 6,
#  'n': 2,
#  ' ': 6,
#  's': 6,
#  't': 1,
#  'a': 5,
#  'c': 3,
#  'l': 1,
#  'p': 1,
#  'r': 2,
#  'd': 1,
#  'm': 2,
#  'o': 3,
#  'u': 1,
#  'h': 2,
#  'y': 1}

# %%
cuenta_letras("hola hola")
# Out:
# {'h': 2, 'o': 2, 'l': 2, 'a': 2, ' ': 1}

# %% [markdown]
# ## Ejercicio 6
# Escribir una función que añada o elimine elementos en una lista. La función necesita los siguientes argumentos:
# * lista: la lista donde se añadirán o eliminarán los elementos
# * comando: "add" o "remove"
# * elemento: Por defecto es None.

# %%
def modifica_lista(lista, comando, elemento=None):
    if comando == "add":
        if elemento is None:
            lista.append(9999)
            print("Añadido el 9999 porque no se introdujo valor en el argumento elemento")
        else:
            lista.append(elemento)
    elif comando == "remove":
        if elemento is None:
            print("No ha introducido el elemento")
        elif elemento not in lista:
            print("El elemento", elemento, "no existe en la lista")
        else:
            lista.remove(elemento)
    else:
        print("error")
    print(lista)

lista = [1, 2, 3]
modifica_lista(lista, "add", 9)
modifica_lista(lista, "add")
modifica_lista(lista, "remove", 2)
modifica_lista(lista, "remove")
modifica_lista(lista, "remove", 10)
modifica_lista(lista, "otra_cosa")
# Out:
# [1, 2, 3, 9]
# Añadido el 9999 porque no se introdujo valor en el argumento elemento
# [1, 2, 3, 9, 9999]
# [1, 3, 9, 9999]
# No ha introducido el elemento
# [1, 3, 9, 9999]
# El elemento 10 no existe en la lista
# [1, 3, 9, 9999]
# error
# [1, 3, 9, 9999]

# %% [markdown]
# ## Ejercicio 7
# Crea una función que reciba un número arbitrario de palabras, y devuelva una frase completa, separando las palabras con espacios.

# %%
def construye_frase(*args):
    return " ".join(args)

construye_frase("Hola", "me", "llamo", "Alberto")
# Out:
# 'Hola me llamo Alberto'

# %% [markdown]
# ## Ejercicio 8
# Escribe un programa que obtenga el enésimo número de la [serie de Fibonacci](https://es.wikipedia.org/wiki/Sucesi%C3%B3n_de_Fibonacci). Tienes que crear una función recursiva con un único argumento.
#
# ```Python
# fibonacci(2) = 1
# fibonacci(4) = 3
# fibonacci(5) = 5
# fibonacci(8) = 21
# ```

# %%
def fibonacci(n):
    if n == 1 or n == 2:
        return 1
    else:
        return fibonacci(n-1) + fibonacci(n-2)

print(fibonacci(1))
print(fibonacci(2))
print(fibonacci(4))
print(fibonacci(5))
print(fibonacci(8))
# Out:
# 1
# 1
# 3
# 5
# 21

# %% [markdown]
# ## Ejercicio 9
# Define en una única celda las siguientes funciones:
# * Función que calcule el área de un cuadrado
# * Función que calcule el area de un triángulo
# * Función que calcule el área de un círculo
#
# En otra celda, calcular el area de:
# * Dos círculos de radio 10 + un triángulo de base 3 y altura 7
# * Un cuadrado de lado = 10 + 3 círculos (uno de radio = 4 y los otros dos de radio = 6) + 5 triángulos de base = 2 + altura = 4

# %%
import math

def area_cuadrado(lado):
    return lado ** 2

def area_triangulo(base, altura):
    return (base * altura) / 2

def area_circulo(radio):
    return math.pi * radio ** 2

# %%
resultado1 = area_circulo(10) * 2 + area_triangulo(3, 7)
print(resultado1)

resultado2 = area_cuadrado(10) + area_circulo(4) + area_circulo(6) * 2 + area_triangulo(2, 4) * 5
print(resultado2)
# Out:
# 638.8185307179587
# 396.46015351590177
